# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("resume_sample_dataset.csv")
df
# Out:
#                                           resume_text           job_role
# 0   Python, Pandas, NumPy, SQL, machine learning, ...     Data Scientist
# 1   HTML, CSS, JavaScript, React, responsive desig...      Web Developer
# 2   Python, scikit-learn, machine learning, deep l...        ML Engineer
# 3   Node.js, Express, REST API, MongoDB, backend d...  Backend Developer
# 4   Excel, Power BI, SQL, business analysis, dashb...       Data Analyst
# 5   Docker, Kubernetes, CI/CD, cloud computing, AW...    DevOps Engineer
# 6   Python, FastAPI, Flask, backend services, API ...  Backend Developer
# 7   C++, data structures, algorithms, OOP, problem...  Software Engineer
# 8   JavaScript, Tailwind CSS, UI design, web appli...      Web Developer
# 9   Python, statistics, hypothesis testing, data c...     Data Scientist
# 10  AWS, EC2, S3, Terraform, monitoring, DevOps au...    DevOps Engineer
# 11  React, Redux, frontend architecture, UI optimi...      Web Developer
# ...
